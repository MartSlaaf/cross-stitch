# %%
# %load_ext autoreload
# %autoreload 2

# %%
from matplotlib import pyplot as plt
# %matplotlib inline

# %%
from scheme_generator import bin_colors, convert_small_pixels, colorize_scheme, get_pdf

# %%
import skimage.io

# %%
img = skimage.io.imread('Lenna.jpg')

# %%
scheme, palette, loss = bin_colors(img, 15)

# %%
scheme_cleared, conversion_map = convert_small_pixels(scheme, palette, 2, 2, 10)

# %%
plt.figure(figsize=(10, 16))
plt.xticks([])
plt.yticks([])
plt.imshow(colorize_scheme(scheme, palette))
plt.show()

# %%
plt.figure(figsize=(10, 16))
plt.xticks([])
plt.yticks([])
plt.imshow(colorize_scheme(scheme_cleared, palette))
plt.show()

# %%
plt.figure(figsize=(16, 10))
plt.imshow(conversion_map)
plt.show()

# %%
get_pdf(scheme_cleared, 'Lenna', 'Lenna', palette)
# Out:
# Lossy conversion from float64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# 0
# 0
